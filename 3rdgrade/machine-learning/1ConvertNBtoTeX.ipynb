# %% [markdown]
# # Конвертирование блокнота Colab  в файл формата TeX

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Этот блокнот является шаблоном для конверитрования болкнотов Colab  в файлы формата TeX

# %% [markdown]
# Откройте данный блокнот.
#
# Загрузите файл со своим блокнотом.

# %% [markdown]
# Выполните команду

# %%
# %%shell
# jupyter nbconvert --to latex /content/drive/MyDrive/python/ml/lab3/1040331.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/python/ml/lab3/1040331.ipynb to latex
# [NbConvertApp] Support files will be in 1040331_files/
# [NbConvertApp] Making directory /content/drive/MyDrive/python/ml/lab3/1040331_files
# [NbConvertApp] Making directory /content/drive/MyDrive/python/ml/lab3/1040331_files
# [NbConvertApp] Making directory /content/drive/MyDrive/python/ml/lab3/1040331_files
# [NbConvertApp] Making directory /content/drive/MyDrive/python/ml/lab3/1040331_files
# [NbConvertApp] Making directory /content/drive/MyDrive/python/ml/lab3/1040331_files
# [NbConvertApp] Writing 53977 bytes to /content/drive/MyDrive/python/ml/lab3/1040331.tex

# %% [markdown]
# Нажмите кнопку обновить; появятся  файл с расширением tex и папка с рисунками

# %% [markdown]
# Создайте архив из папки с рисунками

# %%
# !zip -r /content/drive/MyDrive/python/ml/lab3/file.zip /content/drive/MyDrive/python/ml/lab3/1040331_files
# Out:
#   adding: content/drive/MyDrive/python/ml/lab3/1040331_files/ (stored 0%)
#   adding: content/drive/MyDrive/python/ml/lab3/1040331_files/1040331_33_0.png (deflated 14%)
#   adding: content/drive/MyDrive/python/ml/lab3/1040331_files/1040331_43_0.png (deflated 22%)
#   adding: content/drive/MyDrive/python/ml/lab3/1040331_files/1040331_52_0.png (deflated 22%)
#   adding: content/drive/MyDrive/python/ml/lab3/1040331_files/1040331_113_0.png (deflated 14%)
#   adding: content/drive/MyDrive/python/ml/lab3/1040331_files/1040331_123_0.png (deflated 24%)

# %% [markdown]
# Нажмите кнопку обновить; появится файл с расширением zip

# %% [markdown]
# Скачайте файлы с расширениями tex и zip

# %% [markdown]
# Разверните архив так, чтобы в одном каталоге оказались папка с рисунками и файл с расширением tex

# %% [markdown]
# Откройте файл с расширением tex  в соотвествующем редакторе

# %% [markdown]
# В преамбулу файла с расширением  tex  добавьте подключения пакета поддержки русского языка:
# \usepackage[russian]{babel}

# %% [markdown]
# Примечание. Редактирование tex-файла в режиме онлайн: рекомендуется использовать ресурс https://ru.overleaf.com/
