# %% [markdown]
# # Вводное занятие

# %% [markdown]
# Подключаем библиотеки pandas, matplotlib.pyplot, numpy, stats:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# %% [markdown]
# Создание и вывод простой Series

# %%
mySeries = pd.Series([-2, -1, 0, 1, 2])

mySeries
# Out:
# 0   -2
# 1   -1
# 2    0
# 3    1
# 4    2
# dtype: int64

# %% [markdown]
# Создание простой DataFrame с помощью словаря и её вывод

# %%
city = {'Город': ['Москва', 'Санкт-Петербург', 'Новосибирск', 'Екатеринбург', 'Омск'],
        'Год основания': [1147, 1703, 1893, 1723, 1716],
        'Население': [11.9, 4.9, 1.5, 1.4, 1.1]}

df = pd.DataFrame(city)

df
# Out:
#              Город  Год основания  Население
# 0           Москва           1147       11.9
# 1  Санкт-Петербург           1703        4.9
# 2      Новосибирск           1893        1.5
# 3     Екатеринбург           1723        1.4
# 4             Омск           1716        1.1

# %% [markdown]
# Открываем csv файл как DataFrame

# %%
df = pd.read_csv('/content/InternetSpeed2022.csv')

df
# Out:
#                country  broadband  mobile
# 0               Monaco     261.82     NaN
# 1            Singapore     255.83  105.01
# 2            Hong Kong     254.70   83.58
# 3              Romania     232.17   59.67
# 4          Switzerland     229.96  135.70
# ..                 ...        ...     ...
# 172  Equatorial Guinea       7.95     NaN
# 173              Sudan       7.92   14.51
# 174              Yemen       7.59     NaN
# 175       Turkmenistan       4.11     NaN
# 176               Cuba       4.01   25.02
#
# [177 rows x 3 columns]

# %% [markdown]
# Проверка работы методов head() и tail()

# %%
df.head()
# Out:
#        country  broadband  mobile
# 0       Monaco     261.82     NaN
# 1    Singapore     255.83  105.01
# 2    Hong Kong     254.70   83.58
# 3      Romania     232.17   59.67
# 4  Switzerland     229.96  135.70

# %%
df.tail()
# Out:
#                country  broadband  mobile
# 172  Equatorial Guinea       7.95     NaN
# 173              Sudan       7.92   14.51
# 174              Yemen       7.59     NaN
# 175       Turkmenistan       4.11     NaN
# 176               Cuba       4.01   25.02

# %% [markdown]
# Быстрая оценка данных с помощью метода describe()

# %%
df.describe()
# Out:
#         broadband      mobile
# count  177.000000  136.000000
# mean    72.672825   53.788235
# std     66.461751   43.327121
# min      4.010000    7.270000
# 25%     22.500000   24.402500
# 50%     43.480000   35.825000
# 75%    109.410000   69.205000
# max    261.820000  238.060000

# %% [markdown]
# Сортировка и фильтрация записей

# %%
df.sort_values('mobile', ascending=False).head()
# Out:
#                  country  broadband  mobile
# 15  United Arab Emirates     189.07  238.06
# 9            South Korea     212.57  202.61
# 23                Norway     168.25  177.72
# 42                 Qatar     113.88  172.18
# 14                 China     196.57  165.38

# %% [markdown]
# Удаление строк с пропусками

# %%
df_without_nan = df.dropna()

df_without_nan
# Out:
#          country  broadband  mobile
# 1      Singapore     255.83  105.01
# 2      Hong Kong     254.70   83.58
# 3        Romania     232.17   59.67
# 4    Switzerland     229.96  135.70
# 5        Denmark     227.91  112.03
# ..           ...        ...     ...
# 168      Algeria      10.43   18.10
# 169   Mozambique       9.27   25.02
# 171  Afghanistan       8.26    7.27
# 173        Sudan       7.92   14.51
# 176         Cuba       4.01   25.02
#
# [136 rows x 3 columns]

# %% [markdown]
# Сортировка и фильтрация записей без учёта записей с пропусками

# %%
df_without_nan.sort_values('mobile', ascending=True)
# Out:
#                   country  broadband  mobile
# 171           Afghanistan       8.26    7.27
# 110             Palestine      29.46    7.57
# 128             Venezuela      23.92    7.68
# 82                  Ghana      52.10   12.90
# 140              Tanzania      19.77   13.23
# ..                    ...        ...     ...
# 14                  China     196.57  165.38
# 42                  Qatar     113.88  172.18
# 23                 Norway     168.25  177.72
# 9             South Korea     212.57  202.61
# 15   United Arab Emirates     189.07  238.06
#
# [136 rows x 3 columns]
